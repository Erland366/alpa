# %%
import numpy as np
import pickle

# %%
with open('pickle_objects/objects_iteration500.pkl','rb') as f:
    objects = pickle.load(f)

# %%
objects
# Out:
# {'iter': 500,
#  't_iters': [9.247515201568604,
#   0.025948762893676758,
#   0.02403879165649414,
#   0.023398160934448242,
#   0.0237119197845459,
#   0.023365020751953125,
#   0.023520231246948242,
#   0.02377629280090332,
#   0.02429652214050293,
#   0.024068117141723633,
#   0.02318406105041504,
#   0.02400803565979004,
#   0.02498936653137207,
#   0.024340391159057617,
#   0.0238645076751709,
#   0.025554180145263672,
#   0.026082515716552734,
#   0.02414083480834961,
#   0.024255990982055664,
#   0.023969650268554688,
#   0.024498701095581055,
#   0.02689075469970703,
#   0.024452686309814453,
#   0.024057388305664062,
#   0.025168657302856445,
#   0.024771928787231445,
#   0.02467632293701172,
#   0.02522563934326172,
#   0.025348424911499023,
#   0.024001598358154297,
#   0.025568246841430664,
#   0.025913238525390625,
#   0.02465534210205078,
#   0.026993513107299805,
#   0.024895668029785156,
#   0.026772737503051758,
#   0.02462458610534668,
#   0.02430105209350586,
# ...
