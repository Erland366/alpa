# %%
import numpy as np
import pickle

# %% [markdown]
# # Loading the data

# %%
with open('pickle_objects_observations_throughput/objects_iteration92899.pkl','rb') as f:
    objects = pickle.load(f)
# Out:
# /home/coder/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearRegression from version 1.3.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
count = {k: len(v) for k, v in objects.config_t_iter.items()}

# %%
count
# Out:
# {(12, 1, 1): 100,
#  (20, 1, 1): 100,
#  (28, 1, 1): 100,
#  (36, 1, 1): 100,
#  (44, 1, 1): 100,
#  (52, 1, 1): 100,
#  (60, 1, 1): 100,
#  (68, 1, 1): 41,
#  (24, 2, 1): 100,
#  (40, 2, 1): 100,
#  (56, 2, 1): 100,
#  (72, 2, 1): 100,
#  (88, 2, 1): 100,
#  (104, 2, 1): 100,
#  (120, 2, 1): 100,
#  (136, 2, 1): 1,
#  (48, 4, 1): 100,
#  (80, 4, 1): 100,
#  (112, 4, 1): 100,
#  (144, 4, 1): 100,
#  (176, 4, 1): 100,
#  (208, 4, 1): 100,
#  (240, 4, 1): 100,
#  (272, 4, 1): 100,
#  (280, 4, 1): 100,
#  (84, 4, 1): 100,
#  (60, 4, 1): 100,
#  (88, 4, 1): 100,
#  (92, 4, 1): 100,
#  (76, 4, 1): 100,
#  (96, 4, 1): 100}

# %%
to_delete = [(68, 1, 1),
 (136, 2, 1),
 (272, 4, 1),
 (280, 4, 1),
 (84, 4, 1),
 (60, 4, 1),
 (88, 4, 1),
 (92, 4, 1),
 (76, 4, 1),
 (96, 4, 1)]

for alloc in to_delete:
    del objects.config_t_iter[alloc]

# %%
config_t_iter_1gpu = {k: np.median(np.sort(v)) for k, v in objects.config_t_iter.items() if k[1] == 1}
config_t_iter_2gpu = {k: np.median(np.sort(v)) for k, v in objects.config_t_iter.items() if k[1] == 2}
config_t_iter_4gpu = {k: np.median(np.sort(v)) for k, v in objects.config_t_iter.items() if k[1] == 4}

# %%
X_1gpu = np.array(list(config_t_iter_1gpu.keys()))
y_1gpu = np.array(list(config_t_iter_1gpu.values()))

X_2gpu = np.array(list(config_t_iter_2gpu.keys()))
y_2gpu = np.array(list(config_t_iter_2gpu.values()))

X_4gpu = np.array(list(config_t_iter_4gpu.keys()))
y_4gpu = np.array(list(config_t_iter_4gpu.values()))

# %%
import matplotlib.pyplot as plt

plt.scatter(X_1gpu[:, 0], y_1gpu, label="1 GPU observations")
plt.scatter(X_2gpu[:, 0], y_2gpu, label="2 GPU observations")
plt.scatter(X_4gpu[:, 0], y_4gpu, label="4 GPU observations")
plt.xlabel('Total batch size')
plt.ylabel('T_iter')
# plt.title('Linear regression')
plt.legend()

# %%
X = np.vstack([X_1gpu, X_2gpu, X_4gpu])
y = np.hstack([y_1gpu, y_2gpu, y_4gpu])

# %%
X.shape, y.shape
# Out:
# ((21, 3), (21,))

# %%
all_bs = np.array(list(range(4, 256))).reshape(-1, 1)
gpu1 = np.full(all_bs.shape, 1)
gpu2 = np.full(all_bs.shape, 2)
gpu4 = np.full(all_bs.shape, 4)
gpu8 = np.full(all_bs.shape, 8)
node1 = np.full(all_bs.shape, 1)

all_bs_configs_1gpu = np.hstack([all_bs, gpu1, node1])
all_bs_configs_2gpu = np.hstack([all_bs, gpu2, node1])
all_bs_configs_4gpu = np.hstack([all_bs, gpu4, node1])
all_bs_configs_8gpu = np.hstack([all_bs, gpu8, node1])

# %%
# X_polynomial_term = (X[:, 0] * X[:, 1] * X[:, 2]).reshape(-1, 1)
# X_polynomial = np.hstack([X, X_polynomial_term])

# all_bs_configs_1gpu_polynomial_term = (all_bs_configs_1gpu[:, 0] * all_bs_configs_1gpu[:, 1] * all_bs_configs_1gpu[:, 2]).reshape(-1, 1)
# all_bs_configs_1gpu_polynomial = np.hstack([all_bs_configs_1gpu, all_bs_configs_1gpu_polynomial_term])

# all_bs_configs_2gpu_polynomial_term = (all_bs_configs_2gpu[:, 0] * all_bs_configs_2gpu[:, 1] * all_bs_configs_2gpu[:, 2]).reshape(-1, 1)
# all_bs_configs_2gpu_polynomial = np.hstack([all_bs_configs_2gpu, all_bs_configs_2gpu_polynomial_term])

# all_bs_configs_4gpu_polynomial_term = (all_bs_configs_4gpu[:, 0] * all_bs_configs_4gpu[:, 1] * all_bs_configs_4gpu[:, 2]).reshape(-1, 1)
# all_bs_configs_4gpu_polynomial = np.hstack([all_bs_configs_4gpu, all_bs_configs_4gpu_polynomial_term])

from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(2)
X_polynomial = poly.fit_transform(X)
all_bs_configs_1gpu_polynomial = poly.transform(all_bs_configs_1gpu)
all_bs_configs_2gpu_polynomial = poly.transform(all_bs_configs_2gpu)
all_bs_configs_4gpu_polynomial = poly.transform(all_bs_configs_4gpu)

all_bs_configs_8gpu_polynomial = poly.transform(all_bs_configs_8gpu)

# %%
X_polynomial_to_train = X_polynomial[X_polynomial[:, 2] != 4]
y_to_train = y[X_polynomial[:, 2] != 4]

X_to_train = X[X[:, 1] != 4]

# %%
from pycaret.regression import *
s = setup(data=X, target=y, session_id=123, polynomial_features=True)
# Out:
# <style type="text/css">
# #T_ee08b_row8_col1, #T_ee08b_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ee08b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee08b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ee08b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee08b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ee08b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ee08b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ee08b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ee08b_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ee08b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ee08b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ee08b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_ee08b_row3_col1" class="data row3 col1" >(21, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ee08b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_ee08b_row4_col1" class="data row4 col1" >(21, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ee08b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_ee08b_row5_col1" class="data row5 col1" >(14, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ee08b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_ee08b_row6_col1" class="data row6 col1" >(7, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ee08b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_ee08b_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ee08b_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_ee08b_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ee08b_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_ee08b_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ee08b_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_ee08b_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ee08b_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_ee08b_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ee08b_row12_col0" class="data row12 col0" >Polynomial features</td>
#       <td id="T_ee08b_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ee08b_row13_col0" class="data row13 col0" >Polynomial degree</td>
#       <td id="T_ee08b_row13_col1" class="data row13 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ee08b_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_ee08b_row14_col1" class="data row14 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ee08b_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_ee08b_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ee08b_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_ee08b_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ee08b_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_ee08b_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ee08b_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_ee08b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ee08b_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_ee08b_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ee08b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ee08b_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_ee08b_row20_col1" class="data row20 col1" >9a64</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .          13:23:55
# Status     . . . . . . . . . . . . . . . . . .  Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Lasso Regression
# <style type="text/css">
# #T_a2455 th {
#   text-align: left;
# }
# #T_a2455_row0_col0, #T_a2455_row0_col1, #T_a2455_row0_col2, #T_a2455_row0_col3, #T_a2455_row0_col4, #T_a2455_row0_col5, #T_a2455_row0_col6, #T_a2455_row0_col7 {
#   text-align: left;
# }
# </style>
# <table id="T_a2455">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2455_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a2455_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a2455_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a2455_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a2455_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a2455_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a2455_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a2455_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2455_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_a2455_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_a2455_row0_col1" class="data row0 col1" >0.0218</td>
#       <td id="T_a2455_row0_col2" class="data row0 col2" >0.0009</td>
#       <td id="T_a2455_row0_col3" class="data row0 col3" >0.0225</td>
#       <td id="T_a2455_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_a2455_row0_col5" class="data row0 col5" >0.0183</td>
#       <td id="T_a2455_row0_col6" class="data row0 col6" >0.1159</td>
#       <td id="T_a2455_row0_col7" class="data row0 col7" >0.4620</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/77 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb Cell 16 line 1
# ----> <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X21sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> best = compare_models()
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/regression/functional.py:805, in compare_models(include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, engine, verbose, parallel)
#     670 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#     671 def compare_models(
#     672     include: Optional[List[Union[str, Any]]] = None,
#    (...)
#     687     parallel: Optional[ParallelBackend] = None,
#     688 ):
#     689     """
#     690     This function trains and evaluates performance of all estimators available in the
#     691     model library using cross validation. The output of this function is a score grid
#    (...)
#     803
#     804     """
# --> 805     return _CURRENT_EXPERIMENT.compare_models(
#     806         include=include,
#     807         exclude=exclude,
#     808         fold=fold,
#     809         round=round,
#     810         cross_validation=cross_validation,
#     811         sort=sort,
#     812         n_select=n_select,
#     813         budget_time=budget_time,
#     814         turbo=turbo,
#     815         errors=errors,
#     816         fit_kwargs=fit_kwargs,
#     817         groups=groups,
#     818         experiment_custom_tags=experiment_custom_tags,
#     819         engine=engine,
#     820         verbose=verbose,
#     821         parallel=parallel,
#     822     )
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/regression/oop.py:1122, in RegressionExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, engine, verbose, parallel)
#    1119         self._set_engine(estimator=estimator, engine=eng, severity="error")
#    1121 try:
# -> 1122     return_values = super().compare_models(
#    1123         include=include,
#    1124         exclude=exclude,
#    1125         fold=fold,
#    1126         round=round,
#    1127         cross_validation=cross_validation,
#    1128         sort=sort,
#    1129         n_select=n_select,
#    1130         budget_time=budget_time,
#    1131         turbo=turbo,
#    1132         errors=errors,
#    1133         fit_kwargs=fit_kwargs,
#    1134         groups=groups,
#    1135         experiment_custom_tags=experiment_custom_tags,
#    1136         verbose=verbose,
#    1137         parallel=parallel,
#    1138         caller_params=caller_params,
#    1139     )
#    1141 finally:
#    1142     if engine is not None:
#    1143         # Reset the models back to the default engines
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:794, in _SupervisedExperiment.compare_models(self, include, exclude, fold, round, cross_validation, sort, n_select, budget_time, turbo, errors, fit_kwargs, groups, experiment_custom_tags, probability_threshold, verbose, parallel, caller_params)
#     791 results_columns_to_ignore = ["Object", "runtime", "cutoff"]
#     793 try:
# --> 794     model, model_fit_time = self._create_model(**create_model_args)
#     795     model_results = self.pull(pop=True)
#     796     assert (
#     797         np.sum(
#     798             model_results.drop(
#    (...)
#     802         != 0.0
#     803     )
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1533, in _SupervisedExperiment._create_model(self, estimator, fold, round, cross_validation, predict, fit_kwargs, groups, refit, probability_threshold, experiment_custom_tags, verbose, system, add_to_model_list, X_train_data, y_train_data, metrics, display, model_only, return_train_score, error_score, **kwargs)
#    1530         return model, model_fit_time
#    1531     return model
# -> 1533 model, model_fit_time, model_results, _ = self._create_model_with_cv(
#    1534     model=model,
#    1535     data_X=data_X,
#    1536     data_y=data_y,
#    1537     fit_kwargs=fit_kwargs,
#    1538     round=round,
#    1539     cv=cv,
#    1540     groups=groups,
#    1541     metrics=metrics,
#    1542     refit=refit,
#    1543     system=system,
#    1544     display=display,
#    1545     error_score=error_score,
#    1546     return_train_score=return_train_score,
#    1547 )
#    1549 # end runtime
#    1550 runtime_end = time.time()
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:1126, in _SupervisedExperiment._create_model_with_cv(self, model, data_X, data_y, fit_kwargs, round, cv, groups, metrics, refit, system, display, error_score, return_train_score)
#    1124     model_fit_start = time.time()
#    1125     with redirect_output(self.logger):
# -> 1126         scores = cross_validate(
#    1127             pipeline_with_model,
#    1128             data_X,
#    1129             data_y,
#    1130             cv=cv,
#    1131             groups=groups,
#    1132             scoring=metrics_dict,
#    1133             fit_params=fit_kwargs,
#    1134             n_jobs=n_jobs,
#    1135             return_train_score=return_train_score,
#    1136             error_score=error_score,
#    1137         )
#    1139 model_fit_end = time.time()
#    1140 model_fit_time = np.array(model_fit_end - model_fit_start).round(2)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/model_selection/_validation.py:266, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     263 # We clone the estimator to make sure that all the folds are
#     264 # independent, and that it is pickle-able.
#     265 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 266 results = parallel(
#     267     delayed(_fit_and_score)(
#     268         clone(estimator),
#     269         X,
#     270         y,
#     271         scorers,
#     272         train,
#     273         test,
#     274         verbose,
#     275         None,
#     276         fit_params,
#     277         return_train_score=return_train_score,
#     278         return_times=True,
#     279         return_estimator=return_estimator,
#     280         error_score=error_score,
#     281     )
#     282     for train, test in cv.split(X, y, groups)
#     283 )
#     285 _warn_or_raise_about_fit_failures(results, error_score)
#     287 # For callabe scoring, the return type is only know after calling. If the
#     288 # return type is a dictionary, the error scores can now be inserted with
#     289 # the correct key.
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import svm
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import SGDRegressor
from sklearn import linear_model
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import WhiteKernel, DotProduct, Matern, RBF
from sklearn.kernel_ridge import KernelRidge


# regressor = LinearRegression()
regressor = linear_model.Ridge(alpha=.5)
# kernel = DotProduct() + Matern() + WhiteKernel()
# kernel = KernelRidge()
# kernel = RBF()
# regressor = GaussianProcessRegressor(kernel=kernel)

# regressor.fit(X, y)
regressor.fit(X_polynomial, y)
# regressor.fit(X_polynomial_to_train, y_to_train)

regressor_1gpu = LinearRegression()
regressor_1gpu.fit(X_1gpu, y_1gpu)

regressor_2gpu = LinearRegression()
regressor_2gpu.fit(X_2gpu, y_2gpu)

regressor_4gpu = LinearRegression()
regressor_4gpu.fit(X_4gpu, y_4gpu)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_percentage_error

# y_pred = regressor.predict(X)
# y_pred = regressor.predict(X_polynomial)
y_pred = best.predict(X)

y_1gpu_pred = regressor_1gpu.predict(X_1gpu)
y_2gpu_pred = regressor_2gpu.predict(X_2gpu)
y_4gpu_pred = regressor_4gpu.predict(X_4gpu)

y_error = mean_absolute_percentage_error(y, y_pred)
y_1gpu_error = mean_absolute_percentage_error(y_1gpu, y_1gpu_pred)
y_2gpu_error = mean_absolute_percentage_error(y_2gpu, y_2gpu_pred)
y_4gpu_error = mean_absolute_percentage_error(y_4gpu, y_4gpu_pred)

print(f"y_error: {round(y_error * 100, 2)}%")
print(f"y_1gpu_error: {round(y_1gpu_error * 100, 2)}%")
print(f"y_2gpu_error: {round(y_2gpu_error * 100, 2)}%")
print(f"y_4gpu_error: {round(y_4gpu_error * 100, 2)}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb Cell 18 line 5
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from sklearn.metrics import mean_absolute_percentage_error
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # y_pred = regressor.predict(X)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # y_pred = regressor.predict(X_polynomial)
# ----> <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> y_pred = best.predict(X)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> y_1gpu_pred = regressor_1gpu.predict(X_1gpu)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X23sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> y_2gpu_pred = regressor_2gpu.predict(X_2gpu)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/linear_model/_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/linear_model/_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
#     335     check_is_fitted(self)
# --> 337     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     338     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/base.py:588, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     585     out = X, y
#     587 if not no_val_X and check_params.get("ensure_2d", True):
# --> 588     self._check_n_features(X, reset=reset)
#     590 return out
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/sklearn/base.py:389, in BaseEstimator._check_n_features(self, X, reset)
#     386     return
#     388 if n_features != self.n_features_in_:
# --> 389     raise ValueError(
#     390         f"X has {n_features} features, but {self.__class__.__name__} "
#     391         f"is expecting {self.n_features_in_} features as input."
#     392     )
#
# ValueError: X has 3 features, but LinearRegression is expecting 9 features as input.

# %%
# polynomial_1gpu_predictions = regressor.predict(all_bs_configs_1gpu)
# polynomial_2gpu_predictions = regressor.predict(all_bs_configs_2gpu)
# polynomial_4gpu_predictions = regressor.predict(all_bs_configs_4gpu)

# polynomial_1gpu_predictions = regressor.predict(all_bs_configs_1gpu_polynomial)
# polynomial_2gpu_predictions = regressor.predict(all_bs_configs_2gpu_polynomial)
# polynomial_4gpu_predictions = regressor.predict(all_bs_configs_4gpu_polynomial)

polynomial_1gpu_predictions = predict_model(best, data=all_bs_configs_1gpu)
polynomial_2gpu_predictions = predict_model(best, data=all_bs_configs_2gpu)
polynomial_4gpu_predictions = predict_model(best, data=all_bs_configs_4gpu)

# polynomial_8gpu_predictions = regressor.predict(all_bs_configs_8gpu_polynomial)

throughput_polynomial_1gpu_predictions = all_bs_configs_1gpu[:, 0] / polynomial_1gpu_predictions
throughput_polynomial_2gpu_predictions = all_bs_configs_2gpu[:, 0] / polynomial_2gpu_predictions
throughput_polynomial_4gpu_predictions = all_bs_configs_4gpu[:, 0] / polynomial_4gpu_predictions

# throughput_polynomial_8gpu_predictions = all_bs_configs_8gpu[:, 0] / polynomial_8gpu_predictions

throughput_1gpu_observations = X_1gpu[:, 0] / y_1gpu
throughput_2gpu_observations = X_2gpu[:, 0] / y_2gpu
throughput_4gpu_observations = X_4gpu[:, 0] / y_4gpu
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb Cell 19 line 9
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # polynomial_1gpu_predictions = regressor.predict(all_bs_configs_1gpu)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # polynomial_2gpu_predictions = regressor.predict(all_bs_configs_2gpu)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # polynomial_4gpu_predictions = regressor.predict(all_bs_configs_4gpu)
#    (...)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # polynomial_2gpu_predictions = regressor.predict(all_bs_configs_2gpu_polynomial)
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> # polynomial_4gpu_predictions = regressor.predict(all_bs_configs_4gpu_polynomial)
# ----> <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> polynomial_1gpu_predictions = predict_model(best, data=all_bs_configs_1gpu)
#      <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> polynomial_2gpu_predictions = predict_model(best, data=all_bs_configs_2gpu)
#      <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X24sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> polynomial_4gpu_predictions = predict_model(best, data=all_bs_configs_4gpu)
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/regression/functional.py:1895, in predict_model(estimator, data, round, verbose)
#    1892 if experiment is None:
#    1893     experiment = _EXPERIMENT_CLASS()
# -> 1895 return experiment.predict_model(
#    1896     estimator=estimator,
#    1897     data=data,
#    1898     round=round,
#    1899     verbose=verbose,
#    1900 )
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/regression/oop.py:2188, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2134 def predict_model(
#    2135     self,
#    2136     estimator,
#    (...)
#    2139     verbose: bool = True,
#    2140 ) -> pd.DataFrame:
#    2141     """
#    2142     This function predicts ``Label`` using a trained model. When ``data`` is
#    2143     None, it predicts label on the holdout set.
#    (...)
#    2185
#    2186     """
# -> 2188     return super().predict_model(
#    2189         estimator=estimator,
#    2190         data=data,
#    2191         probability_threshold=None,
#    2192         encoded_labels=False,
#    2193         round=round,
#    2194         verbose=verbose,
#    2195     )
#
# File ~/miniconda3/envs/alpa-adaptdl/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:4943, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4941     y_test_untransformed = self.y_test[self.y_test.index.isin(y_test_.index)]
#    4942 else:
# -> 4943     if y_name in data.columns:
#    4944         data = self._set_index(self._prepare_dataset(data, y_name))
#    4945         target = data[y_name]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'

# %%
plt.rcParams['font.family'] = 'DeJavu Serif'
plt.rcParams['font.serif'] = ['Times New Roman']

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, polynomial_1gpu_predictions, label="2nd degree polynomial regression", linestyle='dashed', c='grey')
plt.plot(all_bs, polynomial_2gpu_predictions, linestyle='dashed', c='grey')
plt.plot(all_bs, polynomial_4gpu_predictions, linestyle='dashed', c='grey')
plt.scatter(X_1gpu[:, 0], y_1gpu, label="1 GPU observations", marker='x')
plt.scatter(X_2gpu[:, 0], y_2gpu, label="2 GPU observations", marker='x')
plt.scatter(X_4gpu[:, 0], y_4gpu, label="4 GPU observations", marker='x')
plt.xlabel('Batch size', fontsize=12)
plt.ylabel('Iteration time (sec)', fontsize=12)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb Cell 21 line 3
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
# ----> <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> plt.plot(all_bs, polynomial_1gpu_predictions, label="2nd degree polynomial regression", linestyle='dashed', c='grey')
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> plt.plot(all_bs, polynomial_2gpu_predictions, linestyle='dashed', c='grey')
#       <a href='vscode-notebook-cell://10.127.79.238:32510/home/coder/alpa-adaptdl/examples/throughput_model_verification/BERT-base/throughput_plots_pycaret.ipynb#X26sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> plt.plot(all_bs, polynomial_4gpu_predictions, linestyle='dashed', c='grey')
#
# NameError: name 'polynomial_1gpu_predictions' is not defined

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, throughput_polynomial_1gpu_predictions, label="2nd degree polynomial regression", linestyle='dashed', c='grey')
plt.plot(all_bs, throughput_polynomial_2gpu_predictions, linestyle='dashed', c='grey')
plt.plot(all_bs, throughput_polynomial_4gpu_predictions, linestyle='dashed', c='grey')
plt.scatter(X_1gpu[:, 0], throughput_1gpu_observations, label="1 GPU observations", marker='x')
plt.scatter(X_2gpu[:, 0], throughput_2gpu_observations, label="2 GPU observations", marker='x')
plt.scatter(X_4gpu[:, 0], throughput_4gpu_observations, label="4 GPU observations", marker='x')
plt.xlabel('Batch size', fontsize=12)
plt.ylabel('Throughput (examples/sec)', fontsize=12)
plt.grid()
plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(0.4, 0.78), fontsize=10)

# %%
regressor_1gpu_predictions = regressor_1gpu.predict(all_bs_configs_1gpu)
regressor_2gpu_predictions = regressor_2gpu.predict(all_bs_configs_2gpu)
regressor_4gpu_predictions = regressor_4gpu.predict(all_bs_configs_4gpu)

# %%
throughput_1gpu_predictions = all_bs_configs_1gpu[:, 0] / regressor_1gpu_predictions
throughput_2gpu_predictions = all_bs_configs_2gpu[:, 0] / regressor_2gpu_predictions
throughput_4gpu_predictions = all_bs_configs_4gpu[:, 0] / regressor_4gpu_predictions

throughput_1gpu_observations = X_1gpu[:, 0] / y_1gpu
throughput_2gpu_observations = X_2gpu[:, 0] / y_2gpu
throughput_4gpu_observations = X_4gpu[:, 0] / y_4gpu

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, regressor_1gpu_predictions, label="1 GPU linear regression", linestyle='dashed')
plt.plot(all_bs, regressor_2gpu_predictions, label="2 GPU linear regression", linestyle='dashed')
plt.plot(all_bs, regressor_4gpu_predictions, label="4 GPU linear regression", linestyle='dashed')
plt.scatter(X_1gpu[:, 0], y_1gpu, label="1 GPU observations", marker='x')
plt.scatter(X_2gpu[:, 0], y_2gpu, label="2 GPU observations", marker='x')
plt.scatter(X_4gpu[:, 0], y_4gpu, label="4 GPU observations", marker='x')
plt.xlabel('Batch size', fontsize=12)
plt.ylabel('Iteration time (sec)', fontsize=12)
plt.grid()
plt.legend()

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, throughput_1gpu_predictions, label="1 GPU model", linestyle='dashed')
plt.plot(all_bs, throughput_2gpu_predictions, label="2 GPU model", linestyle='dashed')
plt.plot(all_bs, throughput_4gpu_predictions, label="4 GPU model", linestyle='dashed')
plt.scatter(X_1gpu[:, 0], throughput_1gpu_observations, label="1 GPU observations", marker='x')
plt.scatter(X_2gpu[:, 0], throughput_2gpu_observations, label="2 GPU observations", marker='x')
plt.scatter(X_4gpu[:, 0], throughput_4gpu_observations, label="4 GPU observations", marker='x')
plt.xlabel('Batch size', fontsize=12)
plt.ylabel('Throughput (examples/sec)', fontsize=12)
plt.grid()
plt.legend()
plt.legend(loc='upper left', bbox_to_anchor=(0.6, 0.87), fontsize=10)

# %%
regressor_1gpu.coef_, regressor_2gpu.coef_, regressor_4gpu.coef_
# Out:
# (array([0.00479348, 0.        , 0.        ]),
#  array([0.00227153, 0.        , 0.        ]),
#  array([0.00113308, 0.        , 0.        ]))

# %%
regressor_1gpu.intercept_, regressor_2gpu.intercept_, regressor_4gpu.intercept_
# Out:
# (0.02192572974932519, 0.03077823208046282, 0.02943616079366107)

# %%
import matplotlib.pyplot as plt

plt.scatter(1, 0.00206749, label="1 GPU regressor slope")
plt.scatter(2, 0.00108904, label="2 GPU regressor slope")
plt.scatter(4, 0.00056805, label="4 GPU regressor slope")
plt.xlabel('GPUs')
plt.ylabel('Slope')
plt.xticks([1, 2, 4])
plt.legend()

# %% [markdown]
# ### What if batch size (x-axis) is per-GPU batch size (although it is not a thing in Alpa)?

# %%
X_1gpu = np.array(list(config_t_iter_1gpu.keys()))
X_1gpu[:,0] = X_1gpu[:,0] / 1
y_1gpu = np.array(list(config_t_iter_1gpu.values()))

X_2gpu = np.array(list(config_t_iter_2gpu.keys()))
X_2gpu[:,0] = X_2gpu[:,0] / 2
y_2gpu = np.array(list(config_t_iter_2gpu.values()))

X_4gpu = np.array(list(config_t_iter_4gpu.keys()))
X_4gpu[:,0] = X_4gpu[:,0] / 4
y_4gpu = np.array(list(config_t_iter_4gpu.values()))

# %%
import matplotlib.pyplot as plt

plt.scatter(X_1gpu[:, 0], y_1gpu, label="1 GPU observations")
plt.scatter(X_2gpu[:, 0], y_2gpu, label="2 GPU observations")
plt.scatter(X_4gpu[:, 0], y_4gpu, label="4 GPU observations")
plt.xlabel('Per-GPU batch size')
plt.ylabel('T_iter')
plt.title('Linear regression')
plt.legend()

# %%
X = np.vstack([X_1gpu, X_2gpu, X_4gpu])
y = np.hstack([y_1gpu, y_2gpu, y_4gpu])

# %%
all_bs = np.array(list(range(64))).reshape(-1, 1)
gpu1 = np.full(all_bs.shape, 1)
gpu2 = np.full(all_bs.shape, 2)
gpu4 = np.full(all_bs.shape, 4)
node1 = np.full(all_bs.shape, 1)

all_bs_configs_1gpu = np.hstack([all_bs, gpu1, node1])
all_bs_configs_2gpu = np.hstack([all_bs, gpu2, node1])
all_bs_configs_4gpu = np.hstack([all_bs, gpu4, node1])

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, regressor.predict(all_bs_configs_1gpu), label="1 GPU model")
plt.plot(all_bs, regressor.predict(all_bs_configs_2gpu), label="2 GPU model")
plt.plot(all_bs, regressor.predict(all_bs_configs_4gpu), label="4 GPU model")
plt.scatter(X[:, 0], y, label="real")
plt.xlabel('Batch size')
plt.ylabel('T_iter')
plt.title('Linear regression')
plt.legend()

# %% [markdown]
# # Overfitting Gaussian processes regression:

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import WhiteKernel, ConstantKernel, RBF, DotProduct, RationalQuadratic

kernel = DotProduct() + RBF() + WhiteKernel(noise_level_bounds=(1e-10, 1e5))
regressor = GaussianProcessRegressor(kernel=kernel)
regressor.fit(X, y)
# Out:
# GaussianProcessRegressor(kernel=DotProduct(sigma_0=1) + RBF(length_scale=1) + WhiteKernel(noise_level=1))

# %%
import matplotlib.pyplot as plt

plt.plot(all_bs, regressor.predict(all_bs_configs_1gpu), label="1 GPU model")
plt.plot(all_bs, regressor.predict(all_bs_configs_2gpu), label="2 GPU model")
plt.plot(all_bs, regressor.predict(all_bs_configs_4gpu), label="4 GPU model")
plt.scatter(X[:, 0], y, label="real")
plt.xlabel('Batch size')
plt.ylabel('T_iter')
plt.title('Gaussian processes regression')
plt.legend()
